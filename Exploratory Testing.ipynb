# %%
import requests
from bs4 import BeautifulSoup
from csv import writer

# %%
url = 'https://www.kijiji.ca/b-cars-trucks/london/forester/k0c174l1700214?price=__7000&price-type=fixed'

# %%
response = requests.get(url)

# %%
html_text = BeautifulSoup(response.text, 'html.parser')

# %%
html_text

# %%
posts = html_text.find_all(class_="info-container")

# %%
print(posts[1].find('a')['href'])
# Out:
# /v-cars-trucks/london/2010-subaru-forester-x-wagon/1430511485

# %%
# Similar to KijijiCarScraper.py except that this will email the URL for all new 
# Ads to the specified email address

import requests
from bs4 import BeautifulSoup
from csv import writer


# Returns the Text if non-empty, and "-" if empty
def process(rawdata):
    if rawdata is None:
        return "N/A"
    else:
        return rawdata.get_text()

 
# Flagged Word List = "As is", "Rebuild", "Rebuilt", "Salvaged". "Salvage"
# This might be good to implement later, but would also take a lot of computation time, so right now just
#    looking for "as is"


def urlscraper(url, fname):
    """
    returns none and creates a CSV file, fname, with the data for all car ads, given a url.
    then sends this CSV file to email_address

    urlscraper: Str Str Str -> None


    :param url: A Kijiji URL that has Car Advertisements
    :param fname: Name of the CSV file that the data gets stored in. Remember to include .csv at the end
    :param email_address: string of email address that the csv will be sent to
    :return: None
    :effects: Creates and writes to a CSV file
    """

    # Pulling the raw html given a URL
    response = requests.get(url)
    html_text = BeautifulSoup(response.text, 'html.parser')
    posts = html_text.find_all(class_="info-container")

    # List of posts from url

    # Going to each ad separately and pulling the data.
    with open(fname, 'w') as csv_file:
        csv_writer = writer(csv_file)
        headers = ["price", "make", "model", "year", "km", "trim", "transmission",
                   "drivetrain", "url", "description"]
        csv_writer.writerow(headers)

        # We're going to want to compare each posts URL against the already existing URLs, and email us if it's new.


        for post in posts:
            url_unique = post.find('a')['href']
            url_root = "https://www.kijiji.ca"
            url = url_root + url_unique

            post_response = requests.get(url)
            post_html_text = BeautifulSoup(post_response.text, 'html.parser')
            post_data = post_html_text.find(class_="attributeListWrapper-828359488")

            if post_data is None: 
                pass
            else:
                price = process(post_html_text.find(class_="priceContainer-2538502416"))
                make = process(post_data.find(itemprop="brand"))
                model = process(post_data.find(itemprop="model"))
                year = process(post_data.find(itemprop="vehicleModelDate"))
                km = process(post_data.find(itemprop="mileageFromOdometer"))
                trim = process(post_data.find(itemprop="vehicleConfiguration"))
                transmission = process(post_data.find(itemprop="vehicleTransmission"))
                description = process(post_html_text.find(class_="descriptionContainer-3544745383"))[11:]
                
                drivetrain = process(post_data.find(itemprop="driveWheelConfiguration"))

                # Writing the line to the file
                csv_writer.writerow([price, make, model, year, km, trim, transmission,
                                    drivetrain, url, description])

        # Repeat as long as there are next pages to be done. This isn't elegant, and possibly not efficient, but
        #   should get the job done?

        # Not going to the next page correctly. Not sure where the problem is, although I suspect it might be something
        #    to do with the very beginning of this while loop (although it may be in the writing to CSV as well).

        # Seems to work with an if statement, but not with a while statement. Not sure why this is???

        # Just kidding, it seems to be working now, but I'm going to leave the previous comments in there just in
        #    case it stops working again, I want some amount of legacy information for troubleshooting.

# %%
urlscraper('https://www.kijiji.ca/b-cars-trucks/london/forester/k0c174l1700214?price=__7000&price-type=fixed', 'testlondonforester.csv')

# %%
url_unique = posts[0].find('a')['href']
url_root = "https://www.kijiji.ca"
url = url_root + url_unique

post_response = requests.get(url)
post_html_text = BeautifulSoup(post_response.text, 'html.parser')
post_data = post_html_text.find(class_="attributeListWrapper-1585172129")

# %%
print(post_html_text)
# Out:
# <!DOCTYPE html>
#
# <!--[if lte IE 8]><html id="reset" class="ie8" lang="en"><![endif]-->
# <!--[if IE 9]><html id="reset" class="ie9" lang="en"><![endif]-->
# <!--[if gt IE 9]><!--><html id="reset" lang="en"><!--<![endif]-->
# <!--[if !IE]><!--><html id="reset" lang="en"><!--<![endif]-->
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link as="style" href="https://ca.classistatic.com/static/V/8137/css/master.theme.css" rel="preload"/>
# <link as="script" href="https://ca.classistatic.com/static/V/8137/js/bootstrap.js" rel="preload"/>
# <link as="script" href="https://ca.classistatic.com/static/V/8137/js/common.js" rel="preload"/>
# <link as="font" crossorigin="" href="//ca.classistatic.com/service-static/frontend-service/Larsseit.92161b1b.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="//ca.classistatic.com/service-static/frontend-service/LarsseitMedium.265c8042.woff2" rel="preload" type="font/woff2"/><link as="style" href="//ca.classistatic.com/service-static/frontend-service/styles.2a5512a0916ef9c27649.css" rel="preload"/><link as="script" href="//ca.classistatic.com/service-static/frontend-service/runtime.de9e72f5.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/vendor.a9da77fd.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/app.80fdf12e.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/shareLinkBar.0d1a4d68.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/viewItemPage.adc94daf.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/footer.447dee18.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/header.73844199.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/en-i18n-json.03e578fe.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/styles.87152f9a.js" rel="preload"/>
# <link as="script" href="//ca.classistatic.com/service-static/frontend-service/svg.95b5bcaf.js" rel="preload"/><title>SAFETIED 2006 Subaru Impreza Wagon | Cars &amp; Trucks | London | Kijiji</title>
# <link href="https://ca.classistatic.com/static/V/8137/img/favicons/apple-touch-icon-new.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://ca.classistatic.com/static/V/8137/img/favicons/favicon-32x32-new.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://ca.classistatic.com/static/V/8137/img/favicons/favicon-16x16-new.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="https://ca.classistatic.com/static/V/8137/img/favicons/faviconNew.ico" rel="shortcut icon"/>
# <meta content="Kijiji" name="apple-mobile-web-app-title"/>
# <meta content="Kijiji" name="application-name"/>
# <meta content="/browserconfig.xml" name="msapplication-config"/>
# <meta content="#2c2f6b" name="theme-color"/>
# <link href="https://plus.google.com/+KijijiCanada" rel="publisher">
# <meta content="2006 Subaru Impreza Wagon - SAFETIED Open to offers. -Rust free body - oiled in winter - rust fixed in the fall -Clean undercarriage -Upgraded suspension - forester SG5 springs, struts, rear trailing arms, front end links, lifted -Recently aligned -No knocks, clunks, creaks. -Bluetooth stereo system -Power windows, cruise control -Plate relocate -Regular oil changes -Aluminum r" name="description"><meta content="app-id=318979520" name="apple-itunes-app">
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="Kijiji" property="og:site_name">
# <meta content="Canada" property="og:country-name"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="E03E7C8B4B4E1A0234A8D2042FD326E8" name="msvalidate.01"/>
# <meta content="1ca862e94bc07ad7" name="yandex-verification"/>
# <meta content="nositelinkssearchbox" name="google"/>
# <meta content="en" http-equiv="content-language"/>
# <meta content="https://i.ebayimg.com/00/s/ODAwWDU5OQ==/z/E88AAOSwzNtc2fIk/$_20.JPG" property="og:image"><meta content="product" property="og:type"><meta content="2006 Subaru Impreza Wagon - SAFETIED Open to offers. -Rust free body - oiled in winter - rust fixed in the fall -Clean undercarriage -Upgraded suspension - forester SG5 springs, struts, rear trailing arms, front end links, lifted -Recently aligned -No knocks, clunks, creaks. -Bluetooth stereo system -Power windows, cruise control -Plate relocate -Regular oil changes -Aluminum r" property="og:description"/><meta content="SAFETIED 2006 Subaru Impreza Wagon | Cars &amp; Trucks | London | Kijiji" property="og:title"/><link href="https://www.kijiji.ca/v-cars-trucks/london/safetied-2006-subaru-impreza-wagon/1433859941" hreflang="x-default" rel="alternate"><link href="https://www.kijiji.ca/v-cars-trucks/london/safetied-2006-subaru-impreza-wagon/1433859941?siteLocale=fr_CA" hreflang="fr" rel="alternate">
# <meta content="https://www.kijiji.ca/v-cars-trucks/london/safetied-2006-subaru-impreza-wagon/1433859941?siteLocale=en_CA" property="og:url"/><meta content="42.967833" property="og:latitude"/><meta content="-81.21332619999998" property="og:longitude"/><meta content="Ontario - London" property="og:locality"/><meta content="london" property="og:region"/><script type="application/ld+json">
# { "@context" : "https://schema.org",
#   "@type" : "Organization",
#   "name" : "Kijiji Canada",
#   "alternateName" : "Kijiji",
#   "url" : "https://www.kijiji.ca/",
#   "sameAs" : [
#     "https://www.facebook.com/Kijiji.ca/",
#     "https://twitter.com/Kijiji",
#     "https://plus.google.com/+KijijiCanada",
#     "https://www.youtube.com/user/kijijicanadacorp",
#     "https://www.linkedin.com/company/kijiji-an-ebay-company",
#     "https://www.wikidata.org/wiki/Q1741191"
#   ],
#   "logo": https://ca.classistatic.com/static/V/8137/img/Kijiji-Canada-Logo-1.jpg
# }
# </script>
# <link href="https://ca.classistatic.com/static/V/8137/css/master.theme.css" rel="stylesheet" type="text/css">
# <link href="https://ca.classistatic.com/static/V/8137/css/vip.theme.css" rel="stylesheet" type="text/css">
# <link href="https://ca.classistatic.com/static/V/8137/css/redesign.theme.css" rel="stylesheet" type="text/css"/>
# <link href="https://ca.classistatic.com/static/V/8137/css/redesign-postad.theme.css" rel="stylesheet" type="text/css"/>
# <link href="//ca.classistatic.com/service-static/frontend-service/styles.2a5512a0916ef9c27649.css" rel="stylesheet" type="text/css"/><script src="https://ca.classistatic.com/static/V/8137/js/bootstrap.js"></script>
# <!--[if lte IE 8]><script defer src="https://ca.classistatic.com/static/V/8137/js/ie8.js"></script><![endif]-->
# <script defer="" src="//cdn.optimizely.com/js/2217630246.js"></script>
# <script src="//www.googletagservices.com/tag/js/gpt.js"></script>
# <script src="https://ca.classistatic.com/static/V/8137/js/lib/prebid-1.25.0.min.js"></script>
# <script>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#
# var gptMasterAdData = gptMasterAdData || {};
# var gptCTMAdData = gptCTMAdData || {};
# var gptSizeMaps = gptSizeMaps || {};
# var gptAdSlots = gptAdSlots || {};
# var gptAdTargeting = gptAdTargeting || [];
# var gptBannerSizeMapping = gptBannerSizeMapping || [];
# </script>
# <script>
#         gptSizeMaps.leaderBoard = {
#             breakPoint: [760, 990],
#             responsive: [
#                 { minWidth: 990, sizes: [[728, 90], [970, 90]] },
#                 { minWidth: 760, sizes: [728, 90] },
#                 { minWidth: 0, sizes: [] }
#             ]
#         };
#         gptSizeMaps.bigBox = {
#             breakPoint: 990,
#             responsive: [
#                 { minWidth: 990, sizes: [[300, 250],[300, 600]] },
#                 { minWidth: 0, sizes: [[300, 250],[320, 50]] }
#             ]
#         };
#         gptSizeMaps.vliBanner = {
#             breakPoint: 840,
#             responsive: [
#                 { minWidth: 840, sizes: [728, 90] },
#                 { minWidth: 0, sizes: [320, 50] }
#             ]
#         };
#         gptSizeMaps.leaderBoardBox = {
#             breakPoint: [760, 990],
#             responsive: [
#                 { minWidth: 990, sizes: [[728, 90], [970, 250]] },
#                 { minWidth: 760, sizes: [728, 90] },
#                 { minWidth: 0, sizes: [[300, 250],[320, 50]] }
#             ]
#         };
#         gptSizeMaps.tabBanner = {
#             breakPoint: 1200,
#             responsive: [
#                 { minWidth: 1200, sizes: [550, 400] },
#                 { minWidth: 0, sizes: [320, 200] }
#             ]
#         };
#         gptSizeMaps.footerBanner = {
#             breakPoint: [760, 990],
#             responsive: [
#                 {minWidth: 990, sizes: [[728, 90], [970, 90]]},
#                 {minWidth: 760, sizes: [728, 90]},
#                 {minWidth: 0, sizes: [[300, 250], [320, 50]]}
#             ]
#         };
#     </script><script>
#
#
# gptMasterAdData['gpt-posted-vip'] = {
#     id: 'gpt-posted-vip',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/postad',
#     sizes: [[728, 90],[970, 250]],sizeMapping: gptSizeMaps.leaderBoardBox,tile: '4',
#     collapse: true,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-posted-vip',
#         breakPoint: gptSizeMaps.leaderBoardBox.breakPoint
#     });
#
#
# gptMasterAdData['gpt-vip-leader'] = {
#     id: 'gpt-vip-leader',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[728, 90]],sizeMapping: gptSizeMaps.leaderBoard,tile: '4',pos: 'top',
#     collapse: false,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-vip-leader',
#         breakPoint: gptSizeMaps.leaderBoard.breakPoint
#     });
#
#
# gptMasterAdData['GPTBigbox'] = {
#     id: 'GPTBigbox',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[300, 250],[300, 600]],sizeMapping: gptSizeMaps.bigBox,tile: '2',pos: 'bottom',
#     collapse: false,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'GPTBigbox',
#         breakPoint: gptSizeMaps.bigBox.breakPoint
#     });
#
#
# gptMasterAdData['gpt-sponsored-left'] = {
#     id: 'gpt-sponsored-left',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[350, 90]],tile: '1',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-right'] = {
#     id: 'gpt-sponsored-right',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[350, 90]],tile: '2',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['ImageLeaderBoard'] = {
#     id: 'ImageLeaderBoard',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewimage',
#     sizes: [[728,90]],sizeMapping: gptSizeMaps.vliBanner,tile: '1',pagetype: 'viewimage',pos: 'top',
#     collapse: false,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'ImageLeaderBoard',
#         breakPoint: gptSizeMaps.vliBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-r2s-vip'] = {
#     id: 'gpt-r2s-vip',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/r2s',
#     sizes: [[728, 90],[970, 250]],sizeMapping: gptSizeMaps.leaderBoardBox,tile: '4',pagetype: 'r2s',
#     collapse: true,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-r2s-vip',
#         breakPoint: gptSizeMaps.leaderBoardBox.breakPoint
#     });
#
#
# gptMasterAdData['hidden-trackable'] = {
#     id: 'hidden-trackable',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru',
#     sizes: [1, 1],
#     collapse: false,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-tab-impression-1'] = {
#     id: 'gpt-sponsored-tab-impression-1',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[1,1]],tile: '1',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-tab-impression-2'] = {
#     id: 'gpt-sponsored-tab-impression-2',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[1,2]],tile: '2',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-tab-impression-3'] = {
#     id: 'gpt-sponsored-tab-impression-3',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[1,3]],tile: '3',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-tab-impression-4'] = {
#     id: 'gpt-sponsored-tab-impression-4',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[1,4]],tile: '4',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-tab-impression-5'] = {
#     id: 'gpt-sponsored-tab-impression-5',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[1,5]],tile: '5',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-sponsored-tab-impression-6'] = {
#     id: 'gpt-sponsored-tab-impression-6',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[1,6]],tile: '6',
#     collapse: true,
#     isBiddable: false
# };
#
#
#
# gptMasterAdData['gpt-vip-footer'] = {
#     id: 'gpt-vip-footer',
#     slot: '/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem',
#     sizes: [[728, 90]],sizeMapping: gptSizeMaps.footerBanner,tile: '5',pos: 'base',
#     collapse: false,
#     isBiddable: false
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-vip-footer',
#         breakPoint: gptSizeMaps.footerBanner.breakPoint
#     });
# </script><script>
#
#         gptAdTargeting.push({ key: 'pagetype', value: 'viewitem' });
#
#         gptAdTargeting.push({ key: 'fueltype', value: 'gasoline' });
#
#         gptAdTargeting.push({ key: 'pt', value: 'VIP' });
#
#         gptAdTargeting.push({ key: 'city', value: 'london' });
#
#         gptAdTargeting.push({ key: 'year', value: '2006' });
#
#         gptAdTargeting.push({ key: 'l1', value: 'carsvehicles' });
#
#         gptAdTargeting.push({ key: 'reg_user', value: 'no' });
#
#         gptAdTargeting.push({ key: 'l2', value: 'cars___trucks' });
#
#         gptAdTargeting.push({ key: 'hn', value: 'kijiji.ca' });
#
#         gptAdTargeting.push({ key: 'l3', value: 'subaru' });
#
#         gptAdTargeting.push({ key: 'lt', value: 'c' });
#
#         gptAdTargeting.push({ key: 'carproof', value: 'true' });
#
#         gptAdTargeting.push({ key: 'range', value: '0' });
#
#         gptAdTargeting.push({ key: 'body', value: 'hatchback' });
#
#         gptAdTargeting.push({ key: 'type', value: 'OFFER' });
#
#         gptAdTargeting.push({ key: 'dt', value: 'all-wheel_drive_awd' });
#
#         gptAdTargeting.push({ key: 'catid', value: '174' });
#
#         gptAdTargeting.push({ key: 'dv', value: 'd' });
#
#         gptAdTargeting.push({ key: 'HBL', value: 'yes' });
#
#         gptAdTargeting.push({ key: 'province', value: 'ontario' });
#
#         gptAdTargeting.push({ key: 'forsaleby', value: 'owner' });
#
#         gptAdTargeting.push({ key: 'g_prebid_version', value: '1.25.0' });
#
#         gptAdTargeting.push({ key: 'price', value: '4700' });
#
#         gptAdTargeting.push({ key: 'um', value: '0' });
#
#         gptAdTargeting.push({ key: 'model', value: 'impreza' });
#
#         gptAdTargeting.push({ key: 'make', value: 'subaru' });
#
#         gptAdTargeting.push({ key: 'ab', value: '0' });
#
#         gptAdTargeting.push({ key: 'ptg', value: ["KCA23868_0", "KCA28709_1", "KCA29068_1", "KCA30417_-99", "KCA30527_0", "KCA30726_2", "KCA30821_-99", "KCA31014_1", "KCA31105_1", "KCA31167_0", "KCA31336_1", "KCA31411_0"] });
#
#         gptAdTargeting.push({ key: 'ot', value: '1' });
#
#         gptAdTargeting.push({ key: 'g_cco', value: 'used' });
#
#         gptAdTargeting.push({ key: 'ct', value: '174' });
#
#         gptAdTargeting.push({ key: 'condition', value: 'used' });
#
#         gptAdTargeting.push({ key: 'g_cm', value: 'subaru' });
#
#         gptAdTargeting.push({ key: 'g_cmo', value: 'impreza' });
#
#         gptAdTargeting.push({ key: 'lc', value: '1700214' });
#
#         gptAdTargeting.push({ key: 'bellfibe', value: 'none' });
#
#         gptAdTargeting.push({ key: 'li', value: 'no' });
#
#         gptAdTargeting.push({ key: 'g_adid', value: '1433859941' });
#
#         gptAdTargeting.push({ key: 'locid', value: '1700214' });
#
#         gptAdTargeting.push({ key: 'g_cy', value: '2006' });
#     </script>
# <script>
# var pbPartnerConfig = pbPartnerConfig || [];
#
#
#     pbPartnerConfig.push({
#         id: 'aol',
#         cpmAdjustment: 0.88,
#         params: {
#             'gpt-rightrail-top':    { network: '9970.1', placement: '4428492' },'gpt-rightrail-bottom': { network: '9970.1', placement: '4428494' },'gpt-vip-leader':       { network: '9970.1', placement: '4428491' },'GPTBigbox':            { network: '9970.1', placement: '4428490' },'gpt-leaderboard-top':  { network: '9970.1', placement: '4428546' },'gpt-top-srp':          { network: '9970.1', placement: '4428515' },'gpt-inline-srp':       { network: '9970.1', placement: '4428522' },'gpt-leaderboard-base': { network: '9970.1', placement: '4428520' },'gpt-skyscraper':       { network: '9970.1', placement: '4428518' },'gpt-leader-bottom':    { network: '9970.1', placement: '4428494' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'appnexus',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { placementId: '10477092' },'gpt-r2s-vip':          { placementId: '10477092' },'gpt-posted-vip':       { placementId: '10477092' },'gpt-rightrail-top':    { placementId: '10477237' },'gpt-rightrail-bottom': { placementId: '10477240' },'gpt-vip-leader':       { placementId: '10477242' },'GPTBigbox':            { placementId: '10477243' },'gpt-leaderboard-top':  { placementId: '10477244' },'gpt-top-srp':          { placementId: '10477245' },'gpt-inline-srp':       { placementId: '10477246' },'gpt-leaderboard-base': { placementId: '10477247' },'gpt-skyscraper':       { placementId: '10477248' },'gpt-leader-bottom':    { placementId: '10477240' },'gpt-sticky':           { placementId: '10477244' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'districtm',
#         cpmAdjustment: 0.9,
#         params: {
#             'ImageLeaderBoard':     { placementId: 9836668 },'gpt-r2s-vip':          { placementId: 9836668 },'gpt-posted-vip':       { placementId: 9836668 },'gpt-rightrail-top':    { placementId: 9836669 },'gpt-rightrail-bottom': { placementId: 9836670 },'gpt-vip-leader':       { placementId: 7058027 },'GPTBigbox':            { placementId: 9527288 },'gpt-leaderboard-top':  { placementId: 9809409 },'gpt-top-srp':          { placementId: 9527281 },'gpt-inline-srp':       { placementId: 7058031 },'gpt-leaderboard-base': { placementId: 9527289 },'gpt-skyscraper':       { placementId: 9527292 },'gpt-leader-bottom':    { placementId: 9836670 },'gpt-sticky':           { placementId: 129907 }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'districtmDMX',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { dmxid: 130920, memberid: 100153 },'gpt-r2s-vip':          { dmxid: 130920, memberid: 100153 },'gpt-posted-vip':       { dmxid: 130920, memberid: 100153 },'gpt-rightrail-top':    { dmxid: 130921, memberid: 100153 },'gpt-rightrail-bottom': { dmxid: 130922, memberid: 100153 },'gpt-vip-leader':       { dmxid: 116615, memberid: 100153 },'GPTBigbox':            { dmxid: 127055, memberid: 100153 },'gpt-leaderboard-top':  { dmxid: 129907, memberid: 100153 },'gpt-top-srp':          { dmxid: 127050, memberid: 100153 },'gpt-inline-srp':       { dmxid: 116617, memberid: 100153 },'gpt-leaderboard-base': { dmxid: 127056, memberid: 100153 },'gpt-skyscraper':       { dmxid: 127058, memberid: 100153 },'gpt-leader-bottom':    { dmxid: 130922, memberid: 100153 }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'ix',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { siteId: '190665' },'gpt-r2s-vip':          { siteId: '190665' },'gpt-posted-vip':       { siteId: '190665' },'gpt-rightrail-top':    { siteId: '190666' },'gpt-rightrail-bottom': { siteId: '190667' },'gpt-vip-leader':       { siteId: '190668' },'GPTBigbox':            { siteId: '190669' },'gpt-leaderboard-top':  { siteId: '190663' },'gpt-top-srp':          { siteId: '190670' },'gpt-inline-srp':       { siteId: '190671' },'gpt-leaderboard-base': { siteId: '190672' },'gpt-skyscraper':       { siteId: '190673' },'gpt-leader-bottom':    { siteId: '190667' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'openx',
#         cpmAdjustment: 0.85,
#         params: {
#             'ImageLeaderBoard':     { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-r2s-vip':          { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-posted-vip':       { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-rightrail-top':    { delDomain: 'kijiji-d.openx.net', unit: '538714687' },'gpt-rightrail-bottom': { delDomain: 'kijiji-d.openx.net', unit: '538714688' },'gpt-vip-leader':       { delDomain: 'kijiji-d.openx.net', unit: '538714689' },'GPTBigbox':            { delDomain: 'kijiji-d.openx.net', unit: '538714690' },'gpt-leaderboard-top':  { delDomain: 'kijiji-d.openx.net', unit: '538714691' },'gpt-top-srp':          { delDomain: 'kijiji-d.openx.net', unit: '538714692' },'gpt-inline-srp':       { delDomain: 'kijiji-d.openx.net', unit: '538714693' },'gpt-leaderboard-base': { delDomain: 'kijiji-d.openx.net', unit: '538714694' },'gpt-skyscraper':       { delDomain: 'kijiji-d.openx.net', unit: '538714696' },'gpt-leader-bottom':    { delDomain: 'kijiji-d.openx.net', unit: '538714688' },'gpt-sticky':           { delDomain: 'kijiji-d.openx.net', unit: '538714691' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'pubmatic',
#         cpmAdjustment: 0.92,
#         params: {
#             'ImageLeaderBoard':     { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-r2s-vip':          { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-posted-vip':       { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-rightrail-top':    { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_TOP_ENGLISH_300x250@300x250' },'gpt-rightrail-bottom': { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_BOTTOM_ENGLISH_300x250@300x250' },'gpt-vip-leader':       { publisherId: '155984', adSlot: 'PUBMATIC_VIEW_ITEM_PAGE_TOP_ENGLISH_728x90@728x90' },'GPTBigbox':            { publisherId: '155984', adSlot: 'PUBMATIC_VIEW_ITEM_PAGE_BOTTOM_ENGLISH_300x250@300x250' },'gpt-leaderboard-top':  { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_TOP_ENGLISH_728x90@728x90' },'gpt-top-srp':          { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_INLINE1_ENGLISH_728x90@728x90' },'gpt-inline-srp':       { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_INLINE2_ENGLISH_728x90@728x90' },'gpt-leaderboard-base': { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_BASEBOARD_ENGLISH_728x90@728x90' },'gpt-skyscraper':       { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_LEFT_RAIL_ENGLISH_160x600@160x600' },'gpt-leader-bottom':    { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_BOTTOM_ENGLISH_300x250@300x250' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'rubicon',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-r2s-vip':          { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-posted-vip':       { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-rightrail-top':    { siteId: '45324', accountId: '12230', zoneId: '582464' },'gpt-rightrail-bottom': { siteId: '45324', accountId: '12230', zoneId: '582466' },'gpt-vip-leader':       { siteId: '45324', accountId: '12230', zoneId: '582470' },'GPTBigbox':            { siteId: '45324', accountId: '12230', zoneId: '582472' },'gpt-leaderboard-top':  { siteId: '45324', accountId: '12230', zoneId: '582474' },'gpt-top-srp':          { siteId: '45324', accountId: '12230', zoneId: '582476' },'gpt-inline-srp':       { siteId: '45324', accountId: '12230', zoneId: '582478' },'gpt-leaderboard-base': { siteId: '45324', accountId: '12230', zoneId: '582480' },'gpt-skyscraper':       { siteId: '45324', accountId: '12230', zoneId: '582482' },'gpt-leader-bottom':    { siteId: '45324', accountId: '12230', zoneId: '582466' },'gpt-sticky':           { siteId: '45324', accountId: '12230', zoneId: '582474' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'criteo',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { zoneId: '1257525' },'gpt-r2s-vip':          { zoneId: '1257525' },'gpt-posted-vip':       { zoneId: '1257525' },'gpt-rightrail-top':    { zoneId: '1257543' },'gpt-rightrail-bottom': { zoneId: '1257537' },'gpt-vip-leader':       { zoneId: '1257526' },'GPTBigbox':            { zoneId: '1257538' },'gpt-leaderboard-top':  { zoneId: '1257527' },'gpt-top-srp':          { zoneId: '1257533' },'gpt-inline-srp':       { zoneId: '1257534' },'gpt-leaderboard-base': { zoneId: '1257531' },'gpt-skyscraper':       { zoneId: '1257539' }
#         }
#     });
# </script>
# <script>
# var pbjs = pbjs || {};
# pbjs.que = pbjs.que || [];
#
#
#
# var PREBID_TIMEOUT = 2000;
# var PREBID_CPM_MAX = 5.00;
#
#
# if (pbPartnerConfig.length > 0) {
#
#
#     var prebidAdUnits = prebidAdUnits || [];
#     var prebidCpmSums = prebidCpmSums || {};
#     var prebidSizes = prebidSizes || [];
#     Kj.Banners.Bidding.constructPrebidAdUnits();
#
#
#     Kj.Banners.Bidding.enableBidderSettings();
#
#
#     if (prebidAdUnits.length > 0) {
#
#
#         pbjs.que.push(function() {
#             pbjs.setConfig({
#                 sizeConfig: prebidSizes,
#                 userSync: {
#                     iframeEnabled: true,
#                     filterSettings: {
#                         iframe: {
#                             bidders: '*',
#                             filter: 'include'
#                         }
#                     }
#                 }
#             });
#             pbjs.onEvent('bidResponse', Kj.Banners.Bidding.monitorCpmTotals);
#             pbjs.aliasBidder('appnexus', 'districtm');
#         });
#
#
#         Kj.Banners.Bidding.requestBidsBeforeGPT(prebidAdUnits, PREBID_TIMEOUT);
#     }
# }
# </script>
# <script>
#
#
# Kj.Banners.Init.pushAdSizeMaps();
# Kj.Banners.Init.pushAdSlots();
# Kj.Banners.Init.pushAdTargeting();
#
#
# googletag.cmd.push(function() {
#     googletag.pubads().set('adsense_background_color', 'FFFFFF');
#
#
#
#     googletag.enableServices();
#
#
# });
# </script>
# <!-- Google Tag Manager -->
# <script>
# var dataLayer = [{"p":{"t":"VIP","pl":"Wildebeest","v":"8137","lng":"en_CA","ua":"python-requests/2.18.4","cfg":{"tabs":["468","399"]}},"c":{"c":{"id":174,"n":"cars \u0026 trucks"},"l0":{"id":0,"n":"Classifieds"},"l1":{"id":27,"n":"Cars \u0026 Vehicles"},"l2":{"id":174,"n":"cars \u0026 trucks"}},"l":{"c":{"id":1700214,"n":"London"},"l0":{"id":0,"n":"Canada"},"l1":{"id":9004,"n":"Ontario"},"l2":{"id":1700214,"n":"London"}},"a":{"id":"1433859941","t":"OFFER","cdt":1557787262,"lpdt":1557787262,"dl":644,"ic":10,"vc":0,"prc":{"amt":470000,"cur":"CAD","t":"FIXED"},"u":{"huid":"-2187941949880021527765712888","at":"FSBO","tg":{"stg":"KCA30417=-99;KCA31411=0;KCA31336=1;KCA31014=1;KCA30527=0;KCA30726=2;KCA31167=0;KCA30821=-99;KCA31105=1;KCA29068=1;KCA28709=1;KCA23868=0"}},"attr":{"vehicletype_s":"used","bluetooth_b":"1","forsaleby_s":"ownr","noofdoors_s":"5","cruisecontrol_b":"1","carmake_s":"subaru","carcolor_s":"blue","carmileageinkms_i":"300000","drivetrain_s":"awd","carmodel_s":"impreza","cartransmission_s":"2","carbodytype_s":"htchbck","carfueltype_s":"gas","caryear_i":"2006","noofseats_s":"5"},"cr":""},"u":{"li":false,"tg":{"stg":"KCA30417=-99;KCA31411=0;KCA31336=1;KCA31014=1;KCA30527=0;KCA30726=2;KCA31167=0;KCA30821=-99;KCA31105=1;KCA29068=1;KCA28709=1;KCA23868=0"},"cdt":1300893081,"rt":"UNDER_2_HOURS"},"d":{"ua":"python-requests/2.18.4"},"ts":"2019-05-13 23:48:57.285+0000"}];
#     (function (w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#     var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src =
#             '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-W4V6');
# </script>
# <!-- End Google Tag Manager --><script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
#     (function(G,o,O,g,L,e){G[g]=G[g]||function(){(G[g]['q']=G[g]['q']||[]).push(
#     arguments)},G[g]['t']=1*new Date})(window,document,'script','_googCsa');
# </script>
# <script src="https://ca.classistatic.com/static/V/8137/js/third-party/aam-dil-v6.12.js"></script>
# <script>
#     var dataAAM = dataAAM || {};
#     var kijijiDil = DIL.create({
#         partner: 'kijiji',
#         uuidCookie: { name: 'aam_uuid', days: 30 }
#     });
#
#
#     gptAdTargeting.forEach(function(targeting) {
#         dataAAM[targeting.key] = targeting.value;
#     });
#
#
#     kijijiDil.api.signals(dataAAM, 'c_').submit();
# </script>
# <!-- Sunset banner for leq IE 10 -->
# <script defer="" type="text/javascript">
#         $(document).ready(function() {
#             if(document.all) {
#                 $('#MainContainer').prepend("<div id=\"IeSunset\">" +
#                     "<h3>Your browser is out of date. Change to a modern browser for a more secure web experience.</h3><ul>" +
#                     "<li class=\"moz\"><a href=\"https://www.mozilla.org/en-US/firefox/new/\" target=\"_blank\" rel=\"noopener noreferrer\"><h4>Mozilla Firefox <span>Download Here</span></h4></a></li>" +
#                     "<li class=\"chrome\"><a href=\"https://www.google.com/chrome/browser/desktop/\" target=\"_blank\" rel=\"noopener noreferrer\"><h4>Google Chrome<span>Download Here</span></h4></a></li>" +
#                     "<li class=\"ie\"><a href=\"https://support.microsoft.com/en-ca/help/17621/internet-explorer-downloads\" target=\"_blank\" rel=\"noopener noreferrer\"><h4>Internet Explorer<span>Download Here</span></h4></a></li>" +
#                     "</ul></div>");
#             }
#         });
#     </script>
# </link></link></link></link></meta></meta></meta></meta></meta></meta></link></head>
# <body class="responsive responsive-dp en" id="PageVIP">
# <div id="FesLoaderTop">
# <script> window.baseUrl="//ca.classistatic.com/service-static/frontend-service"; </script>
# <script> window.boxUrl="//www.kijiji.ca/"; </script>
# </div>
# <script type="text/javascript">
#     var pageTrackingIdentifier = 'View Item Page';
#     var gaEventLabel = 'L1Cat=Cars & Vehicles;L2Cat=cars & trucks;L1Location=Canada;L2Location=London;posting_id=1433859941';
# </script><script defer="" src="https://ca.classistatic.com/static/V/8137/js/sponsors/ads/ads.js"></script>
# <div id="MainContainer">
# <div class="fes-pagelet">
# <div data-fes-id="header"><header class="headerElement-3349737891" data-reactroot="" role="banner"><a class="skipToMain-3679500748 button-1997310527 button__primary-1681489609 button__medium-1066667140" href="#mainPageContent" rel=" noopener noreferrer">Skip to main content</a><div class="printLogo-4110822992"><div class="logo-3282416437" style="visibility:hidden"><a class="logoLink-1425315727" href="/" title="Kijiji"><svg aria-labelledby="kijiji-logo-title" class="icon-459822882 logoLinkIcon-3327055042" focusable="false" height="100%" role="img" width="100%"><title id="kijiji-logo-title">Kijiji</title><use xlink:href="#kijiji-logo"></use></svg><svg aria-labelledby="kijiji-logo-mobile-title" class="icon-459822882 logoLinkIconMobile-2952028495" focusable="false" height="100%" role="img" width="100%"><title id="kijiji-logo-mobile-title">Kijiji</title><use xlink:href="#kijiji-logo-mobile"></use></svg></a></div></div><div class="overlay-1946744954"></div><div class="headerContainer-1051376346"><div class="logoBarWrapper-2331155591"><div class="logoBar-747828107"><div class="logo-3282416437" style="visibility:hidden"><a class="logoLink-1425315727" href="/" title="Kijiji"><svg aria-labelledby="kijiji-logo-title" class="icon-459822882 logoLinkIcon-3327055042" focusable="false" height="100%" role="img" width="100%"><title id="kijiji-logo-title">Kijiji</title><use xlink:href="#kijiji-logo"></use></svg><svg aria-labelledby="kijiji-logo-mobile-title" class="icon-459822882 logoLinkIconMobile-2952028495" focusable="false" height="100%" role="img" width="100%"><title id="kijiji-logo-mobile-title">Kijiji</title><use xlink:href="#kijiji-logo-mobile"></use></svg></a></div><div class="headerTools-2066608048"><div class="headerButtons-3324203939"><a class="headerLinkLanguage-161837588" data-qa-id="language-toggle" href="/?siteLocale=fr_CA" rel="nofollow" title="Français">fr</a><div class="headerButton-4266786553"><a class="headerButtonIconLink-2857253956" data-qa-id="header-link-my-messages" href="/m-msg-my-messages/" rel="nofollow noopener noreferrer" title="My Messages"><svg class="icon-459822882" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-messages"></use></svg><div class="messagesUnreadCount-3285502768"></div></a></div><div class="root-2862412925"><div class="root-1146394843"><a class="link-2454463992 register-4281208362" href="/t-user-registration.html?targetUrl=L3YtY2Fycy10cnVja3MvbG9uZG9uL3NhZmV0aWVkLTIwMDYtc3ViYXJ1LWltcHJlemEtd2Fnb24vMTQzMzg1OTk0MV5GOFExanZnQU9Pc1RhKzdXT2E1WDlBPT0-" rel="nofollow" title="Register">Register</a><span class="or-4281208362"> <!-- -->or<!-- --> </span><a class="link-2454463992" href="/t-login.html?targetUrl=L3YtY2Fycy10cnVja3MvbG9uZG9uL3NhZmV0aWVkLTIwMDYtc3ViYXJ1LWltcHJlemEtd2Fnb24vMTQzMzg1OTk0MV5GOFExanZnQU9Pc1RhKzdXT2E1WDlBPT0-" rel="nofollow" title="Sign In">Sign In</a></div></div><a class="headerButtonPostAd-3592561303" data-qa-id="header-link-post-ad" href="/p-select-category.html" rel="nofollow noopener noreferrer" title="Post ad">Post ad</a></div></div></div></div><div class="searchBarWrapper-3128709573"><form action="/b-search.html" class="searchBar-2782911640"><input name="formSubmit" type="hidden" value="true"/><input name="adIdRemoved" type="hidden" value=""/><input name="adPriceType" type="hidden" value=""/><input name="brand" type="hidden" value=""/><input name="carproofOnly" type="hidden" value="false"/><input name="categoryId" type="hidden" value="0"/><input name="categoryName" type="hidden" value=""/><input name="cpoOnly" type="hidden" value="false"/><input name="dc" type="hidden" value="true"/><input name="gpTopAd" type="hidden" value="false"/><input name="highlightOnly" type="hidden" value="false"/><input name="ll" type="hidden" value=""/><input name="locationId" type="hidden" value="1700214"/><input name="minPrice" type="hidden" value=""/><input name="maxPrice" type="hidden" value=""/><input name="origin" type="hidden" value=""/><input name="pageNumber" ty ...
# <script type="text/javascript">if(rehydrate===undefined){var rehydrate={};}rehydrate["header"]={componentPath:"Shared/Header/Header",props:{}};</script>
# </div>
# <div id="MessageContainer">
# </div>
# <div id="mainPageContent" tabindex="-1">
# <input id="watchlistXsrf" name="ca.kijiji.xsrf.token" type="hidden" value="1557791336518.c2571c729312d830e0a65d2c04d610a588790c899cb564ff052e424bc86517a9"/>
# <div class="fes-pagelet">
# <div data-fes-id="VIP"><div class="page-4182276102" data-reactroot="" id="ViewItemPage"><div></div><div><div class="sticky-outer-wrapper"><div class="sticky-inner-wrapper" style="position:relative;top:0px;z-index:998"><div class="leaderboard-158664762"><div class="banner-2623503948 banner__LEADERBOARD_VIP_LEADER-38807151"><div id="gpt-vip-leader"></div></div></div></div></div></div><div class="breadcrumbs-320621489"><div class="crumbWrapper-2893329203"><button class="crumbButton-554820449">•••</button><ul class="crumbList-626990029" itemscope="" itemtype="http://schema.org/BreadcrumbList"><li class="crumbItem-889225952" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="crumbLink-2878374109" href="//www.kijiji.ca/h-ontario/9004" itemprop="url" rel=" noopener noreferrer"><span itemprop="name">Ontario</span></a></li><li class="crumbItem-889225952" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="crumbLink-2878374109" href="//www.kijiji.ca/h-london/1700214" itemprop="url" rel=" noopener noreferrer"><span itemprop="name">London</span></a></li><li class="crumbItem-889225952" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="crumbLink-2878374109" href="//www.kijiji.ca/b-cars-vehicles/london/c27l1700214" itemprop="url" rel=" noopener noreferrer"><span itemprop="name">Cars &amp; Vehicles</span></a></li><li class="crumbItem-889225952" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><h1 class="crumbH1-3559413592" itemprop="name"><a class="crumbLink-2878374109" href="//www.kijiji.ca/cars?siteLocale=en_CA" itemprop="url" rel=" noopener noreferrer"><span itemprop="name">Cars &amp; Trucks in London</span></a></h1></li><li class="currentCrumb-3831268168">Ad ID <span>1433859941</span></li></ul></div></div><div class="defaultMessages-1522885425"><div class="messageJumpAnchor-4008899198" id="messages"></div><span></span></div><div itemprop="Vehicle" itemscope="" itemtype="http://schema.org/Vehicle"><div class="itemTitleWrapper-1965346928"><div class="mainColumn-1522885425"><div><h1 class="title-2323565163" itemprop="name">SAFETIED 2006 Subaru Impreza Wagon</h1><div class="priceContainer-2538502416"><span class="currentPrice-441857624" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer"><span content="4700.00" itemprop="price">$4,700.00</span><span content="CAD" itemprop="priceCurrency"></span></span></div></div></div><div class="sidebarColumn-1522885425"><div class="itemMeta-4167503528"><div class="datePosted-319944123" content="2019-05-13" itemprop="datePosted">Posted <time datetime="2019-05-13T22:41:02.000Z" title="May 13, 2019 10:41 PM">about an hour ago</time></div><div content="2019-06-12" itemprop="ValidThrough"></div><div class="locationContainer-118575590" itemscope="" itemtype="http://schema.org/Place"><svg class="icon-459822882 locationPin-494649565" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-locationpin"></use></svg><span class="address-3617944557" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">London, ON N5Z</span><a class="mapLink-1573660252" href="#map">(View Map)</a></div></div></div></div><div class="itemInfo-3918032670" id="vip-body"><div class="sticky-outer-wrapper itemActions-1195903285"><div class="sticky-inner-wrapper" style="position:relative;top:0px"><button aria-pressed="false" class="favouriteButton-1804522268" title="Click to add to My Favourites" type="button"><svg class="icon-459822882 favouriteButtonIcon-3229149000" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-heart"></use></svg><span class="favouriteButtonLabel-2715849804">Favourite</span></button><button class="reportAdButton-442308101" title="Report Ad" type="button"><svg class="icon-459822882 flagIcon-1502387607" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-flag"></use></svg><s ...
# <script>
#               gptBannerSizeMapping.push({
#                 name: 'gpt-vip-tab-1',
#                 breakPoint: gptSizeMaps.tabBanner.breakPoint
#               });
#
#               gptCTMAdData['gpt-vip-tab-1'] = function () {
#                 var adSlot = googletag.defineSlot('/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem', [[550, 400]], 'gpt-vip-tab-1');
#                 adSlot.defineSizeMapping(gptSizeMaps.tabBanner.sizeMapping);
#                 adSlot.setTargeting('tile', '1');
#                 adSlot.addService(googletag.pubads());
#                 adSlot.setCollapseEmptyDiv(false);
#
#                 gptAdSlots['gpt-vip-tab-1'] = {
#                   banner: adSlot,
#                   targetedSize: [[550, 400]]
#                 };
#               };
#             </script>
# </div><div class="banner-2623503948 banner__TAB_BANNER-3312650363"><div id="gpt-vip-tab-1"></div></div><div class="disclaimer-645160138 disclaimer__noPadding-251701128">The above message is from an independent, third-party provider and Kijiji is not responsible for its products or services.</div></div></div></div></div><div><div class="banner-2623503948 banner__isCollapsible-1123499182"><div id="gpt-sponsored-tab-impression-2"></div></div><div><div aria-pressed="false" class="container-134269834" role="button" tabindex="0"><div class="logo-505643" style="background-image:url(https://i.ebayimg.com/00/s/MzBYOTA=/z/2jkAAOSwm~1cLh4N/$_12.PNG)"></div><div class="copy-419797175"><h4 class="mainHeader-3009242153">Car Insurance Calculator</h4><h5 class="secondaryHeader-2240572466">Get a quote in 3 minutes for this car</h5></div><div class="dropdown-2883698537"><svg class="icon-459822882 dropdownIcon-3679970273" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-dropdown-chevron"></use></svg></div></div><div class="containerWrapper-1363121908" css="[object Object]" locale="[object Object]" style="height:0"><div class="container-1204814915 container__noPadding-207930496"><div>
# <script>
#               gptBannerSizeMapping.push({
#                 name: 'gpt-vip-tab-2',
#                 breakPoint: gptSizeMaps.tabBanner.breakPoint
#               });
#
#               gptCTMAdData['gpt-vip-tab-2'] = function () {
#                 var adSlot = googletag.defineSlot('/5138/kij.ca.carsvehicles/cars___trucks/subaru/viewitem', [[550, 400]], 'gpt-vip-tab-2');
#                 adSlot.defineSizeMapping(gptSizeMaps.tabBanner.sizeMapping);
#                 adSlot.setTargeting('tile', '2');
#                 adSlot.addService(googletag.pubads());
#                 adSlot.setCollapseEmptyDiv(false);
#
#                 gptAdSlots['gpt-vip-tab-2'] = {
#                   banner: adSlot,
#                   targetedSize: [[550, 400]]
#                 };
#               };
#             </script>
# </div><div class="banner-2623503948 banner__TAB_BANNER-3312650363"><div id="gpt-vip-tab-2"></div></div><div class="disclaimer-645160138 disclaimer__noPadding-251701128">The above message is from an independent, third-party provider and Kijiji is not responsible for its products or services.</div></div></div></div></div></div><div class="showMoreWrapper-4069775982"><div class="showMoreChild-3420331552" style="height:210px;overflow:hidden"><div class="descriptionContainer-3544745383"><h3 class="title-1536205785">Description</h3><div itemprop="description"><p>2006 Subaru Impreza Wagon - SAFETIED</p><p>Open to offers.</p><p>-Rust free body - oiled in winter - rust fixed in the fall
# -Clean undercarriage
# -Upgraded suspension - forester SG5 springs, struts, rear trailing arms, front end links, lifted
# -Recently aligned
# -No knocks, clunks, creaks.
# -Bluetooth stereo system
# -Power windows, cruise control
# -Plate relocate
# -Regular oil changes
# -Aluminum rims come with this vehicle</p><p>300,000kms</p><p>Car is well maintained, drives great, and is cheap on insurance as it has a very high safety rating. Driven daily and cautiously. Only selling as I got something else and can’t afford both vehicles.</p></div></div></div><div class="fadeOut-1831393242 fadeOut__hidden-961765701"></div><button class="showMoreButton-4078245409 showMoreButton__hidden-961765701">Show more</button></div><div class="visitCounter-360898504"><svg class="icon-459822882 visitIcon-1111895863" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-eye"></use></svg><span>0 visits</span></div><div class="itemInfoSidebar-711448371"><div class="sticky-outer-wrapper bigbox-1455796479"><div class="sticky-inner-wrapper" style="position:relative;top:0px"><div class="banner-2623503948 banner__BIGBOX-65379205"><div id="GPTBigbox"></div></div></div></div><div class="root-3303862212 light-3420168793 root-3898296325"><div class="shortCenteredLine-3798463538"></div><div class="line-4062075345"></div><div class="heavyLine-3271829800"></div></div><div class="container-2988607222"><div class="line-2130453910 line__normal-2158048688" style="width:100px"></div><div class="line-2130453910 line__heavy-1181529818" style="width:100%"></div><div class="line-2130453910 line__heavy-1181529818" style="width:100%"></div><div class="line-2130453910 line__heavier-3816919646" style="width:100%"></div></div></div><div class="sponsored-42047613"><h4 class="heading-4169867270">Sponsored Advertisements</h4><div class="images-623005104"><div class="imageA-2254191039"><div class="banner-2623503948 banner__doNotCenter-2640075546 banner__isCollapsible-1123499182 banner__IMAGE_SPONSOR-2375018279"><div id="gpt-sponsored-left"></div></div></div><div class="imageB-2254191039"><div class="banner-2623503948 banner__doNotCenter-2640075546 banner__isCollapsible-1123499182 banner__IMAGE_SPONSOR-2375018279"><div id="gpt-sponsored-right"></div></div></div></div><div class="adsense-3583446083"><div><div id="AdsenseBottom" style="padding:0"></div></div></div><div class="adsense-3583446083"><div class="adsenseShop-3021669206"><div id="AdsenseShop" style="padding:0"></div></div></div></div></div></div><div class="safetyWarningContainer-4054093842"><div class="banner-2623503948 banner__VIP_FOOTER-65379205"><div id="gpt-vip-footer"></div></div><div class="safetyText-133708707">Take steps to make your Kijiji transactions as secure as possible by following our suggested safety tips.<a class="safetyLink-655802477" href="https://help.kijiji.ca/helpdesk/safety/safety-at-kijiji" rel="noopener noreferrer" target="_blank">Read our Safety Tips</a></div></div></div></div>
# <script type="text/javascript">if(rehydrate===undefined){var rehydrate={};}rehydrate["VIP"]={componentPath:"ViewItem/ViewItemPage",props:{}};</script>
# </div>
# </div>
# </div>
# <div class="fes-pagelet">
# ...
# <script type="text/javascript">if(rehydrate===undefined){var rehydrate={};}rehydrate["footer"]={componentPath:"Shared/Footer",props:{}};</script>
# </div>
# <div class="modal-overlay"></div>
# <div id="FesLoader">
# <script type="text/javascript">window.__data={"autosLandingPage":{"loading":{"makes":{"failure":false,"pending":false,"success":false},"models":{"failure":false,"pending":false,"success":false},"inventory":{"failure":false,"pending":false,"success":false}},"makes":[],"models":[],"inventoryCount":null},"config":{"toggleHomepageFeed":false,"requestUrl":"\u002Fv-cars-trucks\u002Flondon\u002Fsafetied-2006-subaru-impreza-wagon\u002F1433859941","togglePriceGuidanceAbTest":true,"toggleNotificationsOnWeb":false,"showAdmarktLink":false,"toggleCarproofBuyerSideError":false,"clientType":{"isTablet":false,"isMobile":false,"isDesktop":true,"device":"UNKNOWN (mobile=false, isApple=false)"},"boxInternalUrl":"\u002Fv-view-details.html","toggleMoveCrossPromotion":true,"profile":{"memberSince":"March 23 2011","isDealer":false,"isDealerInCategory":false,"responsiveness":"UNDER_2_HOURS","isCas":false,"otherAdsUrl":"\u002Fo-profile\u002F60996695","isAdmarkt":false,"showPhoneNumber":false,"isDealerType":false},"requestQueryString":null,"changeLocationURL":null,"searchForm":{"attributeMap":{},"ll":null,"highlightOnly":false,"sortByName":"dateDesc","adPriceType":null,"adIdRemoved":null,"maxPrice":null,"attributeFiltersMax":{},"userId":null,"origin":null,"categoryName":"","keywords":null,"searchView":"LIST","urgentOnly":false,"cpoOnly":false,"gpTopAd":false,"locationId":1700214,"radius":"","attributeFiltersMin":{},"parentCategoryName":null,"address":"London, Ontario","noLocation":false,"minPrice":null,"pageNumber":1,"categoryId":null,"locationPath":"0,9004,1700214","parentCategorySeoUrl":null,"carproofOnly":false,"dc":false},"toggleEnableAutosFeatureCommunication":true,"toggleHomepageFeedNewCatNav":false,"toggleCpoAttribute":false,"toggleR2sOrder":false,"toggleShowPriceTransparency":true,"toggleCarproofRebrand":true,"boxInternalQueryString":"adId=1433859941&requestSource=b&siteLocale=en_CA","adInfo":{"title":"SAFETIED 2006 Subaru Impreza Wagon","seoUrl":"https:\u002F\u002Fwww.kijiji.ca\u002Fv-cars-trucks\u002Flondon\u002Fsafetied-2006-subaru-impreza-wagon\u002F1433859941?siteLocale=en_CA","sharingImageUrl":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDU5OQ==\u002Fz\u002FE88AAOSwzNtc2fIk\u002F$_35.JPG"},"userLoggedIn":false,"hashedUserId":null,"togglePaymentCalculator":true,"toggleProfileReplyRate":true,"toggleMoveCrossPromoInCategorySuggestions":true,"language":"en","toggleRadialSearch":false,"toggleOrganicSeoXpromo":false,"toggleAfshTestVip":false,"VIP":{"isNewCarAd":false,"multiLocationUrl":null,"postersCompanyName":null,"staticMapImageUrl":null,"contactPosterFromName":null,"posterOtherAdsUrl":"\u002Fo-profile\u002F60996695?referral=organic","editAdUrl":"\u002Fp-edit-ad.html?adId=1433859941","adPosted":false,"tempPhoneNumber":null,"isComFree":false,"postersNumberOfActiveAds":1,"media":[{"type":"image","href":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDU5OQ==\u002Fz\u002FE88AAOSwzNtc2fIk\u002F$_59.JPG","thumbnail":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDU5OQ==\u002Fz\u002FE88AAOSwzNtc2fIk\u002F$_14.JPG"},{"type":"image","href":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDYwMA==\u002Fz\u002Ff4IAAOSwyAVc2fIu\u002F$_59.JPG","thumbnail":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDYwMA==\u002Fz\u002Ff4IAAOSwyAVc2fIu\u002F$_14.JPG"},{"type":"image","href":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDYwMA==\u002Fz\u002FJ7QAAOSwillc2fI4\u002F$_59.JPG","thumbnail":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDYwMA==\u002Fz\u002FJ7QAAOSwillc2fI4\u002F$_14.JPG"},{"type":"image","href":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDYwMA==\u002Fz\u002FlfkAAOSwwJVc2fI~\u002F$_59.JPG","thumbnail":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FODAwWDYwMA==\u002Fz\u002FlfkAAOSwwJVc2fI~\u002F$_14.JPG"},{"type":"image","href":"https:\u002F\u002Fi.ebayimg.com\u002F00\u002Fs\u002FNjQwWDQ4MA==\u002Fz\u002FT48AAOSwt6pc2fJC\u002F$_59.JPG","thumbnail":"htt ...
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/runtime.de9e72f5.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/vendor.a9da77fd.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/app.80fdf12e.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/shareLinkBar.0d1a4d68.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/viewItemPage.adc94daf.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/footer.447dee18.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/header.73844199.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/en-i18n-json.03e578fe.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/styles.87152f9a.js"></script>
# <script defer="" src="//ca.classistatic.com/service-static/frontend-service/svg.95b5bcaf.js"></script>
# </div>
# <script type="text/javascript">window.__apolloData={"$ROOT_QUERY.emailAlert":{"alertId":null,"__typename":"EmailAlert"},"ROOT_QUERY":{"emailAlert":{"type":"id","generated":true,"id":"$ROOT_QUERY.emailAlert","typename":"EmailAlert"},"__typename":"SuggestKeywordQuery","geolocation":{"type":"id","generated":true,"id":"$ROOT_QUERY.geolocation","typename":"Geolocation"},"adDetails":{"type":"id","generated":true,"id":"$ROOT_QUERY.adDetails","typename":"AdDetailsQuery"},"contactSection":{"type":"id","generated":true,"id":"$ROOT_QUERY.contactSection","typename":"ContactSectionQuery"},"priceSection":{"type":"id","generated":true,"id":"$ROOT_QUERY.priceSection","typename":"PriceSectionQuery"},"suggestKeyword":{"type":"id","generated":true,"id":"$ROOT_QUERY.suggestKeyword","typename":"SuggestKeyword"}},"$ROOT_QUERY.geolocation":{"geolocation":null,"geolocationError":false,"__typename":"Geolocation"},"$ROOT_QUERY.adDetails":{"description":"","title":"","priceGuidanceQuery":"","isUrgentSelected":false,"__typename":"AdDetailsQuery"},"$ROOT_QUERY.contactSection":{"email":"","phoneNumber":"","__typename":"ContactSectionQuery"},"$ROOT_QUERY.priceSection":{"amount":"","isPriceDrop":false,"isPriceDropBookable":false,"isShowingPriceDropControl":false,"originalAmount":"","priceDropPricing":"","type":"FIXED","__typename":"PriceSectionQuery"},"$ROOT_QUERY.suggestKeyword":{"query":"","categoryId":0,"selected":false,"__typename":"SuggestKeyword"}};</script><script src="https://ca.classistatic.com/static/V/8137/js/pages/cguid.js"></script>
# <script src="https://ca.classistatic.com/static/V/8137/js/common.js"></script>
# <!-- BUNDLE: _ --><!-- END BUNDLE: _ -->
# <!-- BUNDLE: gpt --><!-- END BUNDLE: gpt -->
# <script defer="" src="https://ca.classistatic.com/static/V/8137/js/legacy-page-controllers/watchlistPanel.js" type="text/javascript"></script>
# <div id="WatchlistContainer">
# <header>
# <div class="watchlist-star-small"></div>
# <h3>My Favourites (<span id="WatchListCount"></span>)</h3>
# <div class="watchlist-tab-arrow"></div>
# </header>
# <div class="body">
# <div class="content">
# <div class="title">Recently Added:</div>
# <div class="view-all">
# <a href="/m-watch-list.html">View all</a>
# </div>
# <div id="Watchlist">
# <ul id="WatchlistItems">
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script src="https://ca.classistatic.com/static/V/8137/js/vip.js" type="text/javascript"></script>
# <script src="https://ca.classistatic.com/static/V/8137/js/text/text.js" type="text/javascript"></script>
# <script src="https://ca.classistatic.com/static/V/8137/js/text/afs.js" type="text/javascript"></script>
# <script src="https://ca.classistatic.com/static/V/8137/js/pages/post-limit.js" type="text/javascript"></script>
# <script defer="" src="https://ca.classistatic.com/static/V/8137/js/templates.js"></script>
# <script type="text/javascript">
#     $(document).ready(function () {
#         var data = window.dataLayer ? dataLayer[0] : [];
#         Zoop.init({
#             data: {dl: data},
#             config: {
#                 url: "/j-page-view.json",
#                 token: "1557791336518.c2571c729312d830e0a65d2c04d610a588790c899cb564ff052e424bc86517a9"
#             }
#         });
#         Zoop.callEvent({
#             data: {}
#         });
#     });
# </script>
# <script type="text/javascript">
#     Kj.extVars = {
#         validationMessages : {
#             group : "Please correct the errors below:",
#             req : "Please enter information above.",
#             email : "Please enter a valid email address.",
#             number : "Please enter a valid number.",
#             phone: "Please provide a valid phone number.",
#             maxlength : "Sorry, our limit is {{max}} characters. Please shorten your message.",
#             minlength: "Input needs to be at least {{min}} characters.",
#             numberRange: "Please enter a value between {{min}} and {{max}}.",
#             numberMax: "Please enter a value no greater than {{max}}.",
#             numberMin: "Please enter a value of at least {{min}}.",
#             fileType: "One or more image(s) failed to upload. File format not supported.",
#             fileSize: "One or more image(s) failed to upload. File size limit exceeded.",
#             matching: "Input does not match above",
#             headline: "Please correct the following before continuing:",
#             creditcard: "Please correct your credit card number.",
#             radioButton: "Please select option above.",
#             postalCode: "Please provide a valid Postal Code.",
#             websiteUrl: "Website URL is invalid, please check your input."
#         },
#         tracking : {
#             page: "View Item Page",
#             locId: "1700214",
#             catId: "",
#             adOrUserNotFound: false
#         },
#         domainUrl : ".kijiji.ca;jsessionid=B60CCFFC396230A95CF39DCEE7D8B884",
#         locale: "en_CA",
#         facebook: {
#             requiredPermissions: "We require permission to access your email address, please try again with the correct permissions.",
#             error: "An error has occurred with Facebook login. Please try again."
#         },
#         isTestEnvironment: false,
#         staticUrl: "https://ca.classistatic.com/static/V/8137/"
#
#     };
#
#     $(document).ready(function() {
#
#
#         Kj.Tracking.initTrackAttributeSelection();
#         Kj.Tracking.initTrackPostAdBeginButtons();
#         Kj.Tracking.initTrackUserAccountActions({
#             isDealer: false
#         });
#         Kj.Tracking.initTrackAdActivation();
#         Kj.Tracking.TrackHelpDesk.init();
#         Kj.Tracking.initAddLinkerParam();
#         Kj.initHoverButtons();
#         Kj.initToggleButtons();
#         Kj.initCollapseCategories();
#         Kj.initHistoryBackLink();
#         Kj.Banners.BannerRendered.init();
#         Kj.initPrintLinks();
#         Kj.initAdChoice();
#
#             Kj.Banners.AdBlock.init();
#
#         Belen.Controller.Search.extVars = {
#             staticContentBaseUrl: 'https://ca.classistatic.com/static/V/8137',
#             editWatchlistAjaxUrl: '/j-edit-watchlist.json;jsessionid=B60CCFFC396230A95CF39DCEE7D8B884',
#             getWatchlistEntryAjaxUrl: '/j-get-watchlist-item.json;jsessionid=B60CCFFC396230A95CF39DCEE7D8B884',
#             watchlistTitleAdd: 'Click to add to My Favourites',
#             watchlistTitleRemove: 'Saved to My Favourites'
#         };
#         Belen.Controller.Search.Watchlist.init();
#
#         //Check for undefined override.
#         if (typeof undefined !== 'undefined') {
#             console.warn('HEY! Something is overwriting `undefined`. Don\'t ship!');
#         }
#     });
# </script>
# <script src="//pulsar.ebay.com/plsr/mpe/0/KIJI/9?pld=%5B%7B%22plsUBT%22%3A1%2C%22ea%22%3A%22VIEW%22%2C%22pge%22%3A2351445%2C%22app%22%3A%22KijijiApp%22%7D%5D&amp;getCGuid=1&amp;cache=0.24303798959590495&amp;callback=pulsarCallback" type="text/javascript"></script>
# <noscript>
# <style>
#         .jsonly {
#             display: none;
#         }
#         .jshidden {
#             display: block;
#         }
#     </style>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-W4V6" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#
#
#
#     $(document).ready(function() {
#
#         function checkCookieAndTrackGA(cookieName, action) {
#             var cookie = $.cookie(cookieName);
#             if (cookie !== undefined) {
#                 action();
#                 $.removeCookie(cookieName, {path: '/' });
#             }
#         }
#
#
#
#
#
#         checkCookieAndTrackGA("postAd", Kj.Tracking.initTrackPostAdSuccess);
#         checkCookieAndTrackGA("editAd", Kj.Tracking.initTrackEditAdSuccess);
#
#
#             Kj.PostingLimit.Tracking.init();
#
#     });
#
# </script>
# <form style="display:none">
# <input id="AdsenseQuery" name="query" type="hidden" value="SAFETIED 2006 Subaru Impreza Wagon London cars &amp; vehicles cars &amp; trucks"/>
# <input id="AdsenseQueryShop" name="query" type="hidden" value="cars &amp; trucks"/>
# </form>
# <script>
#     $(document).ready(function () {
#         Kj.Sponsors.init({
#             maxAds: 6,
#             keepTopBar: true
#         });
#
#
#
#
#
#
#
#
#
#
#
#             var adsenseConfig = {
#                 isVIP: true,
#                 test: 'off',
#                 language: 'en',
#                 pageType: 'vip',
#                 csa: {
#                     top: {
#                         number: 0
#                     },
#                     bottom: {
#                         number: 6
#                     },
#                     repeats: 0,
#                     clientId: 'kijiji-ca-vip',
#                     clientIdShop: '',
#                     channel: '0_w_vip_27_174_x_1_o_x+1_w_x_x_x_x_x_x_kca31167_a+kijiji_ca_afs_007+++1_w_x_x_x_x_x_x_kca30726_c+1_w_x_x_x_x_x_x_kca28709_b+1_w_x_x_x_x_x_x_kca29068_b+1_w_x_x_x_x_x_x_kca23868_a+1_w_x_x_x_x_x_x_kca31105_b+1_w_x_x_x_x_x_x_kca31336_b+1_w_x_x_x_x_x_x_kca31411_a+1_w_x_x_x_x_x_x_kca31014_b',
#                     width: '100%'
#                 }
#             };
#
#
#
#             Kj.Adsense.init(adsenseConfig);
#             Kj.Sponsors.chain(Kj.Adsense.api);
#
#
#         Kj.Sponsors.doFilter();
#     });
# </script>
# </body>
# </html>
# </html>

# %%
post_data = post_html_text.find(class_="attributeListWrapper-828359488")

# %%
print(post_data.get_text())
# Out:
# Request CARFAX Canada ReportConditionUsedYear2006MakeSubaruModelImprezaColourBlueBody TypeHatchbackNo. of Doors5No. of Seats5DrivetrainAll-wheel drive (AWD)TransmissionAutomaticFuel TypeGasolineKilometers300,000IncludesBluetoothCruise control

# %%
from datetime import date

today = str(date.today())

# %%
print(today)
# Out:
# 2019-05-13

# %%
type(today)
# Out:
# datetime.date

# %%
# Out:
# str
